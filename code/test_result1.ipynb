# %%
import numpy as np
from numpy import *
import pandas as pd
import os
os.chdir('../../STAT628')

# %%
df_test = pd.read_csv('review_test_results.csv',index_col=0)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_result = df_test.iloc[:,[0,2]]

# %%
df_result.shape
# Out:
# (1321275, 2)

# %%
df_ = df_result.drop(df_result.index[575261])

# %%
import numpy as np
np.where(df_result.isnull()['KaggleID'] == True)
# Out:
# (array([575261]),)

# %%
result = df_.astype(int)

# %%
result = result.rename(index=str, columns={"KaggleID": "ID", "expected": "Expected"})

# %%
result.to_csv('result.csv', index=False)

# %%
result.dtypes
# Out:
# ID          int64
# Expected    int64
# dtype: object

# %%
result
# Out:
#               ID  Expected
# 0              1         2
# 1              2         3
# 2              3         5
# 3              4         5
# 4              5         5
# 5              6         3
# 6              7         5
# 7              8         5
# 8              9         5
# 9             10         4
# 10            11         5
# 11            12         5
# 12            13         4
# 13            14         2
# 14            15         5
# 15            16         5
# 16            17         1
# 17            18         1
# 18            19         4
# 19            20         5
# 20            21         3
# 21            22         1
# 22            23         5
# 23            24         5
# 24            25         5
# 25            26         1
# 26            27         3
# 27            28         3
# 28            29         5
# 29            30         1
# ...          ...       ...
# 1321244  1321245         3
# 1321245  1321246         5
# ...
