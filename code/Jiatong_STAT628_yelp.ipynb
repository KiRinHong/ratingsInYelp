# %%
import json
import pandas as pd
from operator import or_

# %%
import os
os.getcwd()
# Out:
# '/Users/ljt/Documents/Madison/STAT628'

# %%
os.chdir('../../STAT628')

# %%
bus_train = []
for line in open ('business_train.json','r'):
    bus_train.append(json.loads(line))

# %%
[len(bus_train)]
# Out:
# [154606]

# %%
bus_train[0]
# Out:
# {'business_id': 3157,
#  'name': 'Arizona Biltmore Golf Club',
#  'city': 'Phoenix',
#  'state': 'AZ',
#  'postal_code': '85016',
#  'latitude': 33.5221425,
#  'longitude': -112.0184807,
#  'is_open': 0,
#  'attributes': {'GoodForKids': 'False'},
#  'categories': 'Golf, Active Life',
#  'hours': None}

# %%
df_bus_train = pd.DataFrame.from_dict(bus_train)

# %%
df_bus_train.shape
# Out:
# (154606, 11)

# %%
df_bus_train.head(3)
# Out:
#                                           attributes  business_id  \
# 0                           {'GoodForKids': 'False'}         3157
# 1  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...        23732
# 2                                               None        53580
#
#                           categories       city  \
# 0                  Golf, Active Life    Phoenix
# 1  Sushi Bars, Restaurants, Japanese  Charlotte
# 2      Insurance, Financial Services   Goodyear
#
#                                                hours  is_open   latitude  \
# 0                                               None        0  33.522143
# 1  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...        1  35.092564
# 2  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.455613
#
#     longitude                             name postal_code state
# 0 -112.018481       Arizona Biltmore Golf Club       85016    AZ
# 1  -80.859132      Musashi Japanese Restaurant       28210    NC
# 2 -112.395596  Farmers Insurance - Paul Lorenz       85338    AZ

# %%
cols = df_bus_train.columns.tolist()

# %%
newcols = [cols[1],cols[8],cols[3],cols[10],cols[9],cols[6],cols[7],cols[5],cols[0],cols[2],cols[4]]

# %%
df_bus_train_1 = df_bus_train[newcols]
df_bus_train_1.head(3)
df_bus_train_1.shape
# Out:
# (154606, 11)

# %%
df_bus_train_1.to_csv('bus_train_original.csv')

# %%
attributes = df_bus_train['attributes']
hours = df_bus_train['hours']

# %%
attributes.head(5)
# Out:
# 0                             {'GoodForKids': 'False'}
# 1    {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...
# 2                                                 None
# 3    {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...
# 4    {'RestaurantsPriceRange2': '2', 'BusinessParki...
# Name: attributes, dtype: object

# %%
hours.head(4)
# Out:
# 0                                                 None
# 1    {'Monday': '17:30-21:30', 'Wednesday': '17:30-...
# 2    {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# 3    {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...
# Name: hours, dtype: object

# %%
all_attributes = set(attributes[0].keys())
for i in range(1,len(attributes)): 
    if pd.isna(attributes[i])==False:
        all_attributes = all_attributes.union(set(attributes[i].keys()))
len(all_attributes)
# Out:
# 39

# %%
all_attributes = list(all_attributes)

# %%
all_hrs = []
for i in range(len(hours)): 
    if pd.isna(hours[i])==False:
        all_hrs = list(set(all_hrs + list(hours[i].keys())))

# %%
all_hrs
# Out:
# ['Monday', 'Friday', 'Thursday', 'Sunday', 'Saturday', 'Tuesday', 'Wednesday']

# %%
all_attributes[0] in list(attributes[1].keys())
# Out:
# True

# %%
for i in range(len(all_attributes)):
    alist = []
    for j in range(len(attributes)):
            if pd.isna(attributes[j])==False:
                if all_attributes[i] in set(attributes[j].keys()):
                    alist.append(attributes[j][all_attributes[i]])
                else: alist.append('NA')
            else: alist.append('NA')
    df_bus_train_1[all_attributes[i]]=alist
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
for i in range(len(all_hrs)):
    blist = []
    for j in range(len(hours)):
            if pd.isna(hours[j])==False:
                if all_hrs[i] in set(hours[j].keys()):
                    blist.append(hours[j][all_hrs[i]])
                else: blist.append('NA')
            else: blist.append('NA')
    df_bus_train_1[all_hrs[i]]=blist
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df
'ByAppointmentOnly': 'False', 'BusinessAccept...
# 8   {'BikeParking': 'False', 'ByAppointmentOnly': ...
# 9   {'RestaurantsTakeOut': 'True', 'BusinessParkin...
# 10  {'BusinessParking': '{'garage': False, 'street...
# 11  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 12  {'RestaurantsTakeOut': 'True', 'BusinessParkin...
# 13  {'ByAppointmentOnly': 'False', 'BikeParking': ...
# 14  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 15             {'BusinessAcceptsCreditCards': 'True'}
# 16  {'AcceptsInsurance': 'True', 'ByAppointmentOnl...
# 17                            {'GoodForKids': 'True'}
# 18             {'BusinessAcceptsCreditCards': 'True'}
# 19  {'BikeParking': 'False', 'Ambience': '{'romant...
# 20  {'RestaurantsTakeOut': 'True', 'BusinessParkin...
# 21  {'BikeParking': 'True', 'BusinessParking': '{'...
# 22  {'RestaurantsDelivery': 'False', 'RestaurantsP...
# 23  {'RestaurantsPriceRange2': '3', 'BusinessParki...
# 24             {'BusinessAcceptsCreditCards': 'True'}
# 25  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 26                                               None
# 27  {'BusinessParking': '{'garage': False, 'street...
# 28  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 29  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
#
#                                            categories  \
# 0                                   Golf, Active Life
# 1                   Sushi Bars, Restaurants, Japanese
# 2                       Insurance, Financial Services
# 3   Plumbing, Shopping, Local Services, Home Servi...
# 4                          Beauty & Spas, Hair Salons
# 5   Hair Salons, Hair Stylists, Barbers, Men's Hai...
# 6                Nail Salons, Beauty & Spas, Day Spas
# 7       Beauty & Spas, Nail Salons, Day Spas, Massage
# 8   Local Services, Professional Services, Compute...
# 9   Restaurants, Breakfast & Brunch, Mexican, Taco...
# 10  Bars, Nightlife, Pubs, Barbers, Beauty & Spas,...
# 11         Italian, Restaurants, Pizza, Chicken Wings
# 12                                     Bakeries, Food
# 13           Fitness & Instruction, Active Life, Yoga
# 14                               Restaurants, Italian
# 15  Event Planning & Services, Photographers, Prof...
# 16  Trainers, Health & Medical, Active Life, Physi...
# 17                      Arcades, Arts & Entertainment
# 18                            Automotive, Car Dealers
# 19  Nightlife, Arts & Entertainment, Bars, Strip C...
# 20  Sandwiches, Salad, Restaurants, Burgers, Comfo...
# 21  Mexican, Restaurants, Patisserie/Cake Shop, Fo...
# 22                                     Bakeries, Food
# 23  Fashion, Sporting Goods, Men's Clothing, Shopp...
# 24  Car Rental, Windshield Installation & Repair, ...
# 25  Shopping, Home & Garden, Department Stores, Me...
# 26                            Automotive, Auto Repair
# 27  Restaurants, Nightlife, Breakfast & Brunch, Ve...
# 28  Juice Bars & Smoothies, Food, Ice Cream & Froz...
# 29  Home Services, Real Estate, Financial Services...
#
#                                                 hours       Monday  \
# 0                                                None           NA
# 1   {'Monday': '17:30-21:30', 'Wednesday': '17:30-...  17:30-21:30
# 2   {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...     8:0-17:0
# 3   {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...     7:0-23:0
# 4                                                None           NA
# 5   {'Monday': '10:0-19:0', 'Tuesday': '10:0-19:0'...    10:0-19:0
# 6   {'Tuesday': '12:0-18:0', 'Wednesday': '10:0-18...           NA
# 7   {'Tuesday': '9:0-21:0', 'Wednesday': '9:0-21:0...           NA
# 8   {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...     9:0-17:0
# 9   {'Monday': '7:0-0:0', 'Tuesday': '7:0-0:0', 'W...      7:0-0:0
# 10  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...     10:0-1:0
# 11  {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...     10:0-0:0
# 12  {'Tuesday': '11:0-17:0', 'Wednesday': '11:0-17...           NA
# 13  {'Monday': '16:0-23:0', 'Tuesday': '16:0-23:0'...    16:0-23:0
# 14                                               None           NA
# 15  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...      0:0-0:0
# 16  {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...     6:0-22:0
# 17  {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...     11:0-0:0
# 18  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...     9:0-18:0
# 19  {'Thursday': '19:30-2:0', 'Friday': '19:30-3:0...           NA
# 20                                               None           NA
# 21  {'Monday': '11:0-21:0', 'Tuesday': '10:0-21:0'...    11:0-21:0
# 22  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', 